# %% [markdown]
# # CNN 을 활용하여 폐렴 환자 진단하기
# ### 데이터 전처리

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드시 빠르게 설정
AUTOTUNE = tf.data.experimental.AUTOTUNE
# 데이터 이미지 사이즈
IMAGE_SIZE = (180,180)

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv("HOME"), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*'
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 주요 하이퍼 파라터미터
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)

print(len(train_filenames))
print(len(val_filenames))
print(len(test_filenames))
# Out:
# 5216
# 16
# 624

# %%
# train 데이터와 validation 데이터를 모두 filenames 에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/IM-0447-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person614_bacteria_2483.jpeg

# %% [markdown]
# 파일 경로에 NORMAL이 있는지 확인하여 정상 이미지를 카운트
# 파일 경로에 PNEUMONIA 가 있는지 확인하여 폐렴 이미지 카운트

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if 'NORMAL' in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %% [markdown]
# ```tf.data``` instance 로 mini-batch 작업이 가능하다

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"

# %%
# 이미지를 알맞은 형식으로 변환
def decode_img(img):
    img = tf.image.decode_jpeg(img,channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, IMAGE_SIZE)
    return img

# 이미지의 파일 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# Tensorflow에서는 tf.data 파이프라인을 사용해서 학습 데이터를 효율적으로 사용할 수 있도록 해줍니다. tf.data 파이프라인을 이용하여 prepare_for_training() 함수를 정의해서 데이터를 변환시켜주겠습니다.
#
# shuffle()을 사용하며 고정 크기 버퍼를 유지하고 해당 버퍼에서 무작위로 균일하게 다음 요소를 선택합니다.
#
# repeat()를 사용하면 epoch를 진행하면서 여러 번 데이터셋을 불러오게 되는데, 이때 repeat()를 사용한 데이터셋의 경우 여러 번 데이터셋을 사용할 수 있게 해줍니다.
# 예를 들어, 100개의 데이터를 10번 반복하면 1000개의 데이터가 필요하게 됩니다. repeat()를 사용하면 자동으로 데이터를 맞춰줍니다.
#
# batch()를 사용하면 BATCH_SIZE에서 정한 만큼의 배치로 주어집니다.
# 예를 들어, 100개의 데이터를 10개의 배치로 나누게 되면 각 배치에는 10개의 데이터로 나뉘게 됩니다.
#
# prefetch()를 사용하면 학습 데이터를 나눠서 읽어오기 때문에, 첫 번째 데이터를 GPU에서 학습하는 동안 두 번째 데이터를 CPU에서 준비할 수 있어 리소스의 유휴 상태를 줄일 수 있습니다.

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5, math.ceil(BATCH_SIZE/5), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis('off')
        
image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### CNN 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16,3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16,3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### 데이터 imbalance 처리
# Normal 데이터보다 Pneumonia 데이터의 수가 비교적 많음
#
# ```weight balancing```
#
# 특정 클래스의 데이터에 더 큰 loss 값을 갖도록자가중치를 부여하는 방법

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print("Weight for NORMAL: {:.2f}".format(weight_for_0))
print("Weight for PNUEMONIA: {:.2f}".format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNUEMONIA: 0.67

# %% [markdown]
# ### 모델 훈련하기

# %%
with tf.device('/GPU:0'):
    model = build_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss = 'binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data = val_ds,
        validation_steps = VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 81s 227ms/step - loss: 0.4333 - accuracy: 0.7804 - precision: 0.9381 - recall: 0.7512 - val_loss: 0.9868 - val_accuracy: 0.7365 - val_precision: 0.7365 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 57s 220ms/step - loss: 0.2373 - accuracy: 0.9117 - precision: 0.9669 - recall: 0.9115 - val_loss: 1.4742 - val_accuracy: 0.7375 - val_precision: 0.7375 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.1870 - accuracy: 0.9310 - precision: 0.9751 - recall: 0.9302 - val_loss: 0.2796 - val_accuracy: 0.8644 - val_precision: 0.8442 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.1979 - accuracy: 0.9262 - precision: 0.9746 - recall: 0.9236 - val_loss: 0.0878 - val_accuracy: 0.9673 - val_precision: 0.9933 - val_recall: 0.9621
# Epoch 5/25
# 261/261 [==============================] - 60s 232ms/step - loss: 0.1361 - accuracy: 0.9462 - precision: 0.9830 - recall: 0.9441 - val_loss: 0.0878 - val_accuracy: 0.9702 - val_precision: 0.9933 - val_recall: 0.9660
# Epoch 6/25
# 261/261 [==============================] - 64s 247ms/step - loss: 0.1178 - accuracy: 0.9535 - precision: 0.9896 - recall: 0.9477 - val_loss: 0.8969 - val_accuracy: 0.6962 - val_precision: 1.0000 - val_recall: 0.5875
# Epoch 7/25
# 261/261 [==============================] - 56s 214ms/step - loss: 0.1366 - accuracy: 0.9461 - precision: 0.9867 - recall: 0.9400 - val_loss: 0.0639 - val_accuracy: 0.9788 - val_precision: 0.9895 - val_recall: 0.9817
# Epoch 8/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.1383 - accuracy: 0.9464 - precision: 0.9826 - recall: 0.9437 - val_loss: 0.1111 - val_accuracy: 0.9558 - val_precision: 1.0000 - val_recall: 0.9397
# Epoch 9/25
# 261/261 [==============================] - 56s 216ms/step - loss: 0.1038 - accuracy: 0.9636 - precision: 0.9923 - recall: 0.9591 - val_loss: 0.0713 - val_accuracy: 0.9721 - val_precision: 0.9706 - val_recall: 0.9922
# Epoch 10/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.1155 - accuracy: 0.9579 - precision: 0.9860 - recall: 0.9568 - val_loss: 0.2108 - val_accuracy: 0.9231 - val_precision: 0.9122 - val_recall: 0.9908
# Epoch 11/25
# 261/261 [==============================] - 55s 213ms/step - loss: 0.1056 - accuracy: 0.9614 - precision: 0.9880 - recall: 0.9589 - val_loss: 0.0567 - val_accuracy: 0.9769 - val_precision: 0.9933 - val_recall: 0.9751
# Epoch 12/25
# 261/261 [==============================] - 55s 212ms/step - loss: 0.0780 - accuracy: 0.9744 - precision: 0.9941 - recall: 0.9715 - val_loss: 0.0753 - val_accuracy: 0.9702 - val_precision: 0.9919 - val_recall: 0.9673
# Epoch 13/25
# 261/261 [==============================] - 56s 213ms/step - loss: 0.1283 - accuracy: 0.9448 - precision: 0.9902 - recall: 0.9356 - val_loss: 0.1415 - val_accuracy: 0.9413 - val_precision: 0.9273 - val_recall: 0.9987
# Epoch 14/25
# 261/261 [==============================] - 56s 213ms/step - loss: 0.1137 - accuracy: 0.9625 - precision: 0.9893 - recall: 0.9599 - val_loss: 0.0566 - val_accuracy: 0.9817 - val_precision: 0.9869 - val_recall: 0.9882
# Epoch 15/25
# 261/261 [==============================] - 55s 211ms/step - loss: 0.0944 - accuracy: 0.9671 - precision: 0.9905 - recall: 0.9648 - val_loss: 0.3662 - val_accuracy: 0.9087 - val_precision: 0.9552 - val_recall: 0.9190
# Epoch 16/25
# 261/261 [==============================] - 56s 213ms/step - loss: 0.0892 - accuracy: 0.9639 - precision: 0.9903 - recall: 0.9602 - val_loss: 0.2019 - val_accuracy: 0.9221 - val_precision: 0.9957 - val_recall: 0.8980
# Epoch 17/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.0748 - accuracy: 0.9720 - precision: 0.9917 - recall: 0.9704 - val_loss: 0.0703 - val_accuracy: 0.9779 - val_precision: 0.9908 - val_recall: 0.9791
# Epoch 18/25
# 261/261 [==============================] - 56s 214ms/step - loss: 0.0935 - accuracy: 0.9682 - precision: 0.9904 - recall: 0.9662 - val_loss: 0.1117 - val_accuracy: 0.9577 - val_precision: 0.9489 - val_recall: 0.9961
# Epoch 19/25
# 261/261 [==============================] - 56s 214ms/step - loss: 0.0670 - accuracy: 0.9732 - precision: 0.9929 - recall: 0.9706 - val_loss: 0.1031 - val_accuracy: 0.9683 - val_precision: 0.9656 - val_recall: 0.9921
# Epoch 20/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.0838 - accuracy: 0.9735 - precision: 0.9935 - recall: 0.9708 - val_loss: 0.0497 - val_accuracy: 0.9817 - val_precision: 0.9882 - val_recall: 0.9869
# Epoch 21/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.0650 - accuracy: 0.9750 - precision: 0.9930 - recall: 0.9737 - val_loss: 0.0644 - val_accuracy: 0.9769 - val_precision: 0.9960 - val_recall: 0.9725
# Epoch 22/25
# 261/261 [==============================] - 56s 214ms/step - loss: 0.0935 - accuracy: 0.9600 - precision: 0.9928 - recall: 0.9541 - val_loss: 0.0659 - val_accuracy: 0.9788 - val_precision: 0.9768 - val_recall: 0.9948
# Epoch 23/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.0891 - accuracy: 0.9686 - precision: 0.9901 - recall: 0.9679 - val_loss: 0.0843 - val_accuracy: 0.9683 - val_precision: 0.9959 - val_recall: 0.9607
# Epoch 24/25
# 261/261 [==============================] - 56s 216ms/step - loss: 0.0704 - accuracy: 0.9763 - precision: 0.9933 - recall: 0.9747 - val_loss: 0.0608 - val_accuracy: 0.9837 - val_precision: 0.9921 - val_recall: 0.9856
# Epoch 25/25
# 261/261 [==============================] - 56s 216ms/step - loss: 0.0509 - accuracy: 0.9781 - precision: 0.9970 - recall: 0.9735 - val_loss: 0.0544 - val_accuracy: 0.9788 - val_precision: 0.9831 - val_recall: 0.9882

# %%
fig, ax = plt.subplots(1,4, figsize=(20,3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall {recall}')
# Out:
# 39/39 [==============================] - 6s 141ms/step - loss: 1.2269 - accuracy: 0.7324 - precision: 0.7016 - recall: 0.9949
# Loss: 1.2268788814544678,
# Accuracy: 0.7323718070983887,
# Precision: 0.7016274929046631,
# Recall 0.9948717951774597

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)
    return image, label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.map(
            augment,
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)
